# %% [markdown]
# <h1>getting books data</h1>

# %%
import requests
from requests.models import Response

res: Response = requests.get("https://simple-books-api.glitch.me/books")

print(
    f"""
Text: {res.text} Type: {type(res.text)}
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Text: [{"id":1,"name":"The Russian","type":"fiction","available":true},{"id":2,"name":"Just as I Am","type":"non-fiction","available":false},{"id":3,"name":"The Vanishing Half","type":"fiction","available":true},{"id":4,"name":"The Midnight Library","type":"fiction","available":true},{"id":5,"name":"Untamed","type":"non-fiction","available":true},{"id":6,"name":"Viscount Who Loved Me","type":"fiction","available":true}] Type: <class 'str'>
# Status: 200 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:42:03 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '417', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"1a1-MfqhfTYtZO2sguD1mJq8Vf41WjU"'} Type: <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# <h1>Authorization</h1>

# %%
import requests
from requests.models import Response

data1: dict[str, str] = {"clientName": "Postman", "clientEmail": "devvshayan@gmail.com"}
res: Response = requests.post(
    "https://simple-books-api.glitch.me/api-clients/", json=data1
)

print(
    f"""
Text: {res.text}
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Text: {"error":"API client already registered. Try a different email."}
# Status: 409 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:39:05 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '65', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"41-rjAEsJfLskSzU5wzBOncJcKHOOY"'} Type: <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# <h1>Placing order</h1>

# %%
Header: dict = {
    "Authorization": "Bearer f5da396ca985c7a38470c99d78837bd91d7e0d4388873e3e94076db7fbf69727"
}

Data2: dict[id, str] = {"bookId": 3, "customerName": "ali"}
res: Response = requests.post(
    "https://simple-books-api.glitch.me/orders", headers=Header, json=Data2
)
print(
    f"""
Text: {res.text}
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Text: {"created":true,"orderId":"xVOcDoNe2gHY-02q3CkKB"}
# Status: 201 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:39:07 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '50', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"32-5r3HYH4DZJDqKr7J/zjvF3G/W7c"'} Type: <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# <h1>Updating an order</h1>

# %%
Header: dict = {
    "Authorization": "Bearer f5da396ca985c7a38470c99d78837bd91d7e0d4388873e3e94076db7fbf69727"
}
orderId = "ZD8Z3cKfM6BWbkz6uAb8H"

data3 = {"customerName": "Ali"}
res: Response = requests.patch(
    f"https://simple-books-api.glitch.me/orders/{orderId}", headers=Header, json=data3
)
print(
    f"""
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Status: 404 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:39:09 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '51', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"33-BeMAJzVPlUVcugxPrhkv/H7YsgI"'} Type: <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# <h1>Deleting an order</h1>

# %%
Header: dict = {
    "Authorization": "Bearer f5da396ca985c7a38470c99d78837bd91d7e0d4388873e3e94076db7fbf69727"
}
orderId = "ZD8Z3cKfM6BWbkz6uAb8H"

data3 = {"customerName": "Ali"}
res: Response = requests.delete(
    f"https://simple-books-api.glitch.me/orders/{orderId}", headers=Header, json=data3
)
print(
    f"""
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Status: 404 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:39:11 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '51', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"33-BeMAJzVPlUVcugxPrhkv/H7YsgI"'} Type: <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# <h1>Get all orders</h1>

# %%
Header: dict = {
    "Authorization": "Bearer f5da396ca985c7a38470c99d78837bd91d7e0d4388873e3e94076db7fbf69727"
}
res: Response = requests.get(
    f"https://simple-books-api.glitch.me/orders", headers=Header
)
print(
    f"""
Text: {res.text}
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Text: [{"id":"o4itIXxPL1Zz8UDG40sYs","bookId":1,"customerName":"shayan","createdBy":"5bdcdcda8f53f9371e84db21294fc574f25f4c2e514561345d817c26f8d68e38","quantity":1,"timestamp":1715589239571},{"id":"4y0d6VlrpZwJmkUxLUZgE","bookId":3,"customerName":"ali","createdBy":"5bdcdcda8f53f9371e84db21294fc574f25f4c2e514561345d817c26f8d68e38","quantity":1,"timestamp":1715589497985}]
# Status: 200 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:38:30 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '366', 'Connection': 'keep-alive', 'x-powered-by': 'Express', 'etag': 'W/"16e-9F05WPmr+za0DctEZfdrySqZ90s"'} Type: <class 'requests.structures.CaseInsensitiveDict'>

# %% [markdown]
# <h1>Get single order</h1>

# %%
Header: dict = {
    "Authorization": "Bearer f5da396ca985c7a38470c99d78837bd91d7e0d4388873e3e94076db7fbf69727"
}
orderId = "o4itIXxPL1Zz8UDG40sYs"

data3 = {"customerName": "Ali"}
res: Response = requests.get(
    f"https://simple-books-api.glitch.me/orders/{orderId}", headers=Header, json=data3
)
print(
    f"""
Text: {res.text}
Status: {res.status_code} Type: {type(res.status_code)}
Header: {res.headers} Type: {type(res.headers)}"""
)
# Out:
# Text: {"id":"o4itIXxPL1Zz8UDG40sYs","bookId":1,"customerName":"shayan","createdBy":"5bdcdcda8f53f9371e84db21294fc574f25f4c2e514561345d817c26f8d68e38","quantity":1,"timestamp":1715589239571}
# Status: 200 Type: <class 'int'>
# Header: {'Date': 'Mon, 13 May 2024 08:39:14 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '183', 'Connection': 'close', 'x-powered-by': 'Express', 'etag': 'W/"b7-1Dd/zqfYfPIW51F0JhX+8iEitB0"'} Type: <class 'requests.structures.CaseInsensitiveDict'>
